# %% [markdown]
# <h2> LDA

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
url = "https://raw.githubusercontent.com/ricki0313/Pattern_Recognition_final_project_2025/refs/heads/main/W3_unsupervised_learning/labeled_features.csv"
df = pd.read_csv(url)
df.head(3)
# Out:
#    Unnamed: 0  Customer ID  Recency_scaled  Frequency_scaled  Monetary_scaled
# 0           0      12346.0        2.334858         -0.424675         8.359634  \
# 1           1      12347.0       -0.905199          0.354080         0.251046
# 2           2      12348.0       -0.175186         -0.035297        -0.028547
#
#    AvgUnitPrice_scaled  UniqueItems_scaled  AvgQuantPerOrder_scaled  cluster
# 0            -0.100146           -0.708687                60.891574        3
# 1            -0.053249            0.486336                -0.028273        1
# 2             0.037994           -0.462653                 0.022638        1
